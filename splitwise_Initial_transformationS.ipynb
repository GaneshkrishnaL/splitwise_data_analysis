# %%
import pandas as pd

# %%
confidence=pd.read_csv(r'C:\Users\laksh\Downloads\confidence.csv')

# %%
confidence.columns
# Out:
# Index(['Date', 'Description', 'Category', 'Cost', 'Currency', 'Surya',
#        'Ganesh Krishna Lakshmisetty', 'kanna karthik reddy',
#        'Sayed Mohammad Sohail', 'Gurudatta Tej Marupudi', 'K Nithin',
#        'Saimanassagar (removed)', 'Sai Gopal (removed)'],
#       dtype='object')

# %%
confidence['Description'] = confidence['Description'].str.lower().str.replace('[^\w\s]', '')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\w'
# <>:1: SyntaxWarning: invalid escape sequence '\w'
# C:\Users\laksh\AppData\Local\Temp\ipykernel_14928\2887251039.py:1: SyntaxWarning: invalid escape sequence '\w'
#   confidence['Description'] = confidence['Description'].str.lower().str.replace('[^\w\s]', '')

# %%
confidence
# Out:
#            Date    Description            Category   Cost Currency  Surya  \
# 0    2022-11-02        halal 🍗           Groceries  21.78      USD  -5.44
# 1    2022-11-03        popyees             General   5.19      USD  -1.30
# 2    2022-11-03      uber eats                Taxi   9.66      USD   7.24
# 3    2022-11-03      home depo             General  23.72      USD  -3.95
# 4    2022-11-04      all ubers                Taxi  33.01      USD  -5.50
# ..          ...            ...                 ...    ...      ...    ...
# 771  2024-05-01         tissue  Household supplies  23.00      USD  -3.83
# 772  2024-05-01           sams             General  11.00      USD  -2.20
# 773  2024-05-01        walmart  Household supplies  25.50      USD  -5.10
# 774  2024-05-01        walmart  Household supplies  40.63      USD  32.51
# 775  2024-05-02  total balance                                 USD -72.55
#
#      Ganesh Krishna Lakshmisetty  kanna karthik reddy  Sayed Mohammad Sohail  \
# ...

# %% [markdown]
# ## priniting unique description values

# %%
unique_descriptions = confidence['Description'].unique()
print(unique_descriptions)
# Out:
# ['halal 🍗' 'popyees' 'uber eats' 'home depo' 'all ubers' 'pizza'
#  'orbit pencil' 'dollar' 'bananas' 'wall mart' 'c pr 4' 'braums'
#  'bombay bazaar' 'zen leasing personal' 'zen 2' 'zen#3' 'zen owner'
#  'chick fil a' 'microwave' 'patel(11/11)' 'chic chic chic🐓🐔' 'braumy'
#  'india grill' 'india grill veg' 'tip' 'tempered glass '
#  'india grill lyft' 'cab to zen' 'uhaul' 'nachos' 'patel(11/19)' 'roti'
#  'desi bro' 'laxmi' 'water' 'walmart' 'veg pizza' 'chicken pizza' 'costco'
#  'nestle' 'milk' 'pods 2' 'import food land' 'temple '
#  'settle all balances' 'toll ' 'pro 5' 'desi bros' 'surya paid sayed m.'
#  'walmart milk' 'surya paid ganesh k.' 'nanglo' 'kfc popcorn'
#  'mcd mocha frape' 'patel, choc(12/4)' 'desi ' 'pista house'
#  'guru walmart ' 'hyd house' 'banana' 'spread' 'kroger ' 'desi' 'shawarma'
#  'fries' 'avatar ' 'ice cream' 'insurance ' 'cheese cake ' 'chip chip'
#  'cheesecake factory' 'desi bazaar' 'braums ' 'beer' 'patel' 'water case '
# ...

# %%
value_counts = confidence['Description'].value_counts()
print(len(value_counts))
# Out:
# 405

# %% [markdown]
# ## cleaning description column by mapping and standardizing

# %%
mapping = {
    'wall mart': 'walmart',
    'walmart': 'walmart',
    'wally': 'walmart',
    'walmart ': 'walmart',
    'wallmart': 'walmart',
    'walmart saruku': 'walmart',
    'walmart lite': 'walmart',
    'walmart chobani': 'walmart',
    'walmart eggs': 'walmart',
    'walmart 🍊🥔🍅': 'walmart',
    'walmart- eggs& more': 'walmart',
    'walmart ' : 'walmart',
    'walmart tide order': 'walmart',
    'walmart online': 'walmart',
    'walmart veggies': 'walmart',
    'wal-mart, sams, bombay bazar': 'walmart',
    'wal-shrimp&more': 'walmart',
    'desi brothers': 'Indian groceries',
    'desi': 'Indian groceries',
    'patel': 'Indian groceries',
    'rice': 'Indian groceries',
    'chapati': 'Indian groceries',
    'kfc': 'American Fast Foods',
    'mc donald': 'American Fast Foods',
    'mcd': 'American Fast Foods',
    'mcdonald': 'American Fast Foods',
    'dominos': 'American Fast Foods',
    'popeyes': 'American Fast Foods',
    'panda express': 'American Fast Foods',
    'chick fil a': 'American Fast Foods',
    'tacobell': 'American Fast Foods',
    'costco': 'Costco & similar',
    'kroger': 'Costco & similar',
    'dollar general': 'Costco & similar',
    'dollar': 'Costco & similar',
    'dollar choc': 'Costco & similar',
    'dollar ': 'Costco & similar',
    'water case': 'water',
    'india grill': 'Indian restaurants',
    'india grill veg': 'Indian restaurants',
    'india bazaar': 'Indian restaurants',
    'pista house': 'Indian restaurants',
    'saregama': 'Indian restaurants',
    'swadeshi': 'Indian restaurants',
    'mirchi': 'Indian restaurants',
    'saregama purpuleeee': 'Indian restaurants',
    'indian corner ': 'Indian restaurants',
    'golconda': 'Indian restaurants',
    'foodistan': 'Indian restaurants',
    'anakeren': 'Indian restaurants',
    'desi district': 'Indian restaurants',
    'nanglo': 'Indian restaurants',
    'milk': 'Milk and Beverages',
    'coke': 'Milk and Beverages',
    'mountain dew': 'Milk and Beverages',
    'hot chocolate': 'Milk and Beverages',
    'fiesta': 'Milk and Beverages',
    'p express': 'Milk and Beverages',
    'ice tea': 'Milk and Beverages',
    'beer': 'Milk and Beverages',
    'sprite': 'Milk and Beverages',
    'cool drinks': 'Milk and Beverages',
    'sare tea': 'Milk and Beverages',
    'pani puri': 'Milk and Beverages',
    'tea ': 'Milk and Beverages',
    'choco milk': 'Milk and Beverages',
    'choco milk ': 'Milk and Beverages',
    'almond milk': 'Milk and Beverages',
    'almond milk ': 'Milk and Beverages',
    'sare yogurt': 'Milk and Beverages',
    'milk(2)': 'Milk and Beverages',
    'pods 2': 'Milk and Beverages',
    'nestle': 'Milk and Beverages'
}

confidence['Description'] = confidence['Description'].replace(mapping)

# %%
value_counts = confidence['Description'].value_counts()
print(len(value_counts))
# Out:
# 351

# %%
confidence.shape
# Out:
# (776, 13)

# %% [markdown]
# ## removing rows containing paid & 'settle all balances', ex : saimanassagar paid sayed m.

# %%
confidence = confidence[~confidence['Description'].str.contains('paid', case=False)]
confidence = confidence[~confidence['Description'].str.contains('settle all balances', case=False)]

# %%
confidence.shape
# Out:
# (593, 13)

# %%
value_counts = confidence['Description'].value_counts()
print(value_counts)
# Out:
# Description
# walmart               57
# Indian groceries      37
# Milk and Beverages    26
# braums                26
# Costco & similar      20
#                       ..
# curd                   1
# on protein             1
# costco gas             1
# 🍆🥕🥕halal🥔🥦🥦🍅🍅          1
# total balance          1
# Name: count, Length: 325, dtype: int64

# %%
import re
uber_lyft_pattern = re.compile(r'\b(ride|rides|lyft|uber|ubers|cab)\b', flags=re.IGNORECASE)
food_chains_pattern = re.compile(r'\b(kfc|pizza|taco|mc\s?donald|mcdonald|dominos|popyees|popeyes|panda\s?express|chick\s?fil\s?a|tacobell)\b', flags=re.IGNORECASE)
indian_groceries_pattern = re.compile(r'\b(patel|bombay\s?bazaar|desi\s?brothers|bros|bombay|laxmi|dosa|curd|desi)\b', flags=re.IGNORECASE)

def replace_values(description):
    if uber_lyft_pattern.search(description):
        return 'Uber_and_Lyft'
    elif food_chains_pattern.search(description):
        return 'American Fast Foods'
    elif any(word in description.lower() for word in ['halal', 'chicken', 'chic']):
        return 'Halal Chicken'
    elif indian_groceries_pattern.search(description):
        return 'Indian groceries'
    else:
        return description
confidence['Description'] = confidence['Description'].apply(replace_values)

# %%
unique_descriptions = confidence['Description'].unique()
print(unique_descriptions)
# Out:
# ['Halal Chicken' 'American Fast Foods' 'Uber_and_Lyft' 'home depo'
#  'orbit pencil' 'Costco & similar' 'bananas' 'walmart' 'c pr 4' 'braums'
#  'Indian groceries' 'zen leasing personal' 'zen 2' 'zen#3' 'zen owner'
#  'microwave' 'braumy' 'Indian restaurants' 'tip' 'tempered glass ' 'uhaul'
#  'nachos' 'roti' 'water' 'Milk and Beverages' 'import food land' 'temple '
#  'toll ' 'pro 5' 'walmart milk' 'mcd mocha frape' 'guru walmart '
#  'hyd house' 'banana' 'spread' 'kroger ' 'shawarma' 'fries' 'avatar '
#  'ice cream' 'insurance ' 'cheese cake ' 'chip chip' 'cheesecake factory'
#  'braums ' 'water case ' 'mat' 'sayam kaalam…..' 'qt donuts' 'cabaret'
#  'tom thumb' 'brita' 'soap him' 'soap mysore' 'oasis lake and gas '
#  'shawarma austin' 'parking' 'super 8' 'reddy dabha ' 'austin fusion'
#  'austin tropical drink ' 'gas' 'boating' "dunkin' " 'momos'
#  'mckinney falls' 'zen fine' 'family dollar choc,pista' 'ginger hopper'
# ...

# %%
additional_mapping = {
    'walmart': 'Walmart',
    'braums': 'Braums',
    'costco': 'Costco & similar',
    'uber': 'Uber_and_Lyft',
    'lyft': 'Uber_and_Lyft',
    'gas': 'Indian groceries',
    'halal chicken': 'Halal Chicken',
    'milk': 'Milk and Beverages',
    'beverages': 'Milk and Beverages',
    'kfc': 'American Fast Foods',
    'mcdonald': 'American Fast Foods',
    'popeyes': 'American Fast Foods',
    'dominos': 'American Fast Foods',
    'panda express': 'American Fast Foods',
    'chick fil a': 'American Fast Foods',
    'tacobell': 'American Fast Foods',
    'indian groceries': 'Indian groceries',
    'desi': 'Indian groceries',
    'patel': 'Indian groceries',
    'bombay bazaar': 'Indian groceries',
    'desi brothers': 'Indian groceries',
    'bros': 'Indian groceries',
    'dosa': 'Indian groceries',
    'curd': 'Indian groceries',
    'chips': 'Chips and Snacks',
    'sarigama': 'Indian groceries',
    'panda': 'American Fast Foods',
    'fruits walmart': 'Walmart',
    'kroger': 'Costco & similar',
    'mangoes': 'Indian groceries',
    'ranch': 'Walmart',
    'sling': 'Alcoholic Beverages',
    'mushroom': 'Vegetables',
    'bar': 'Bar & Pub',
    'braums & milk': 'Braums',
    'biryani': 'Indian restaurants',
    'lemon': 'Indian groceries',
    'hangers': 'Household',
    'mug': 'Household',
    'spices': 'Indian groceries',
    'filter & walmart': 'Walmart',
    'sam’s': 'Walmart',
    'chunks': 'Indian groceries',
    'hukum': 'Movie',
    'kettle': 'Household',
    'bis': 'Indian groceries',
    'braums milk': 'Braums',
    'gap shirt': 'Gas',
    'tax gap': 'Gas',
    'foodistaan': 'Indian restaurants',
    'bread and cheese': 'Bakery & Dairy',
    'bounty': 'Household',
    'almond ooo': 'Indian groceries',
    'choco': 'Gas',
    'saregamapa purpuleeee': 'Indian groceries',
    '101 express': 'Indian restaurants',
    'tv 3 months': 'Electronics',
    'pinstack': 'Entertainment',
    'costco water': 'Costco & similar',
    'groceries': 'Indian groceries',
    'sari sari punugulu': 'Indian groceries',
    'kroger bread': 'Costco & similar',
    'rice bag 2': 'Indian groceries',
    'momo': 'Indian restaurants',
    'walmart egmil..': 'Walmart',
    'tresleches': 'Gas',
    'tax india': 'Gas',
    'chapter-2': 'Movie',
    'tikka bowls': 'Indian restaurants',
    'grocery పరాయి gas': 'Gas',
    'tifiin station': 'Indian restaurants',
    'grocery gas': 'Gas',
    'srh vs mi 1:2': 'Movie',
    '(tillu)^2': 'Movie',
    'birthday- indopak': 'Indian restaurants',
    'indopak oil': 'Indian groceries',
    'nithin cake': 'Gas',
    'kanna cake': 'Gas',
    'ugadhi saruku': 'Indian restaurants',
    'pastery': 'Gas',
    'coconut': 'Walmart',
    'sarigama + d e s i': 'Indian restaurants',
    'indian corner': 'Indian groceries',
    'walmart apr 2nd': 'Walmart',
    'eggs apr 2nd': 'Walmart',
    'sams water and sour cream': 'Costco & similar',
    'baby goat': 'Halal Chicken',
    'pitza': 'American Fast Foods',
    'blender': 'Household',
    'tissue': 'Household',
    'ganesh oats': 'Indian groceries',
    'watersam': 'Indian groceries',
    'kroger milk': 'Costco & similar',
    'h&m': 'Unkown',
    'tv 2 months close': 'Household',
    'choc': 'American Fast Foods',
    'kroger eggs&more': 'Costco & similar',
    'kroger fruits / drinks': 'Costco & similar',
    'walmart water': 'Walmart',
    'tacoooooo': 'American Fast Foods',
    'mountain fries': 'American Fast Foods',
    'little india': 'Indian restaurants',
    'egg holic': 'Indian restaurants',
    'sams': 'Costco & similar',
    'వాల్మార్ట్ ఆన్లైన్': 'Walmart',
    'పిస్తా హౌస్': 'Indian restaurants',
    'starter': 'Indian restaurants',
    'apricot': 'Costco & similar',
    'tomatoes': 'Walmart',
    'sams rice and tissue': 'Costco & similar',
    'tv battery': 'Household',
    'veggies only': 'Walmart',
    'apple': 'Walmart',
    'choco milk 3': 'Milk and Beverages',
    'amazon': 'Online Shopping',
    'ck': 'Gas',
    'dish liquid': 'Household',
    'animal singh': 'Movie',
    'go puff': 'Milk and Beverages',
    'paneer malai': 'Indian restaurants',
    'donuts': 'Milk and Beverages',
    'salt': 'Indian groceries',
    'ice cream': 'Milk and Beverages',
    'cheese cake': 'Milk and Beverages',
    'chip chip': 'Walmart',
    'cheesecake factory': 'Trip',
    'water case': 'Household',
    'mat': 'Household',
    'sayam kaalam…..': 'Milk and Beverages',
    'qt donuts': 'Desserts',
    'cabaret': 'Entertainment',
    'tom thumb': 'Walmart',
    'brita': 'Household',
    'soap him': 'Household',
    'soap mysore': 'Household',
    'oasis lake and gas': 'Gas',
    'shawarma austin': 'Indian restaurants',
    'parking': 'Trip',
    'super 8': 'Trip',
    'reddy dabha': 'Indian restaurants',
    'austin fusion': 'Indian restaurants',
    'austin tropical drink': 'Beverages',
    'boating': 'Trip',
    'dunkin\'': 'American Fast Foods',
    'momos': 'Indian restaurants',
    'mckinney falls': 'Trip',
    'zen fine': 'Indian restaurants',
    'family dollar choc,pista': 'Chocolates',
    'insurance': 'Insurance',
    'avatar': 'Movie',
    'sandal soap': 'Household',
    'fries': 'Fries',
    'home depo': 'Household',
    'orbit pencil': 'Household',
    'bananas': 'Fruits',
    'c pr 4': 'Movie',
    'zen leasing personal': 'Unknown',
    'zen 2': 'Unknown',
    'zen#3': 'Unknown',
    'zen owner': 'Unknown',
    'microwave': 'Appliances',
    'braumy': 'Braums',
    'tip': 'Movie',
    'tempered glass': 'Household',
    'uhaul': 'Transportation',
    'nachos': 'Walmart',
    'roti': 'Indian restaurants',
    'import food land': 'Indian groceries',
    'temple': 'Movie',
    'toll': 'Movie',
    'pro 5': 'Household',
    'walmart milk': 'Walmart',
    'mcd mocha frape': 'American Fast Foods',
    'guru walmart': 'Walmart',
    'hyd house': 'Indian restaurants',
    'spread': 'Walmart',
    'shawarma': 'American Fast Foods',
    'ginger hopper': 'American Fast Foods',
    'wing nachos ques': 'Walmart',
    'burger': 'American Fast Foods',
    'beer lanj': 'Milk and Beverages ',
    'bread n spread': 'Bakery & Dairy',
    'wallammart': 'Walmart',
    'mntn dew': 'Milk and Beverages ',
    'brookside': 'Chocolates',
    'plantain chips': 'Chips and Snacks',
    'macronies': 'Milk and Beverages',
    'go puff party': 'Milk and Beverages',
    'cakes': 'Milk and Beverages',
    'cake for 148': 'Milk and Beverages',
    'aluminium foil': 'Household',
    'braums icream': 'Braums',
    'milkuuu': 'Milk and Beverages',
    'cost pizz': 'American Fast Foods',
    'rice & veggies': 'Groceries',
    'sweet corn': 'Vegetables',
    'snacks': 'American Fast Foods',
    'prawns': 'Walmart',
    'tv may': 'Household',
    'braum': 'Braums',
    'silku': 'Clothing',
    'gold shake': 'Beverages',
    '👁️👁️👹🦅🦅🦉': 'Movie',
    'mandi': 'Indian restaurants',
    'shrimp': 'Movie',
    'chocobar': 'Milk and Beverages',
    'halllalalla': 'Halal Chicken',
    'icecream': 'Movie',
    'cream spread': 'Walmart',
    'chor tv': 'Household',
    'kwality irving': 'Indian restaurants',
    '🔝🏌️‍♂️⛳️': 'Movie',
    't shirt': 'Clothing',
    'trimmer': 'Appliances',
    'wine glasses': 'Milk and Beverages',
    'family 💲': 'Movie',
    'pathaan': 'Indian restaurants',
    'casio': 'Household',
    'dg': 'Costco & similar',
    'mcd': 'American Fast Foods',
    'fry pan': 'Household',
    'monks': 'Indian restaurants',
    'apples': 'Indian groceries',
    'track': 'Movie',
    'costco gas': 'Costco & similar',
    'on protein': 'Milk and Beverages ',
    'extra veggies': 'Indian groceries',
    'u haul': 'Household',
    'waffle house': 'American Fast Foods',
    '🇮🇳bazaar': 'Indian groceries',
    'pecan cookies': 'Cookies',
    'cost co': 'Costco & similar',
    'whipping cream': 'Dairy',
    'saregamapa': 'Indian restaurants',
    'sams': 'Costco & similar',
    'water': 'Costco & similar',
    'oil': 'Indian groceries',
    'braums': 'Braums',
    'banana': 'Costco & similar',
    'kawan': 'Indian groceries',
    'rice bag': 'Indian groceries',
    'kroger': 'Costco & similar',
    'eggs': 'Costco & similar',
    'ramen': 'Indian groceries',
    'tomato': 'Costco & similar',
    'bread': 'Costco & similar',
    'sams water': 'Costco & similar',
    'ifl': 'Halal Chicken',
    'aldi': 'Indian groceries',
    'coke': 'Milk and Beverages ',
    'socks': 'Movie',
    'salaar': 'Movie',
    'toll': 'Movie',
    'adda cafe': 'Indian restaurants',
    'sarigama': 'Indian groceries',
    'gas': 'Gas',
    'qt': 'Milk and Beverages',
    'cake': 'Desserts',
    'bbw': 'Bath & Body Works',
    'biryani': 'Indian restaurants',
    'pears': 'Indian groceries',
    'raid': 'Household',
    'maggi': 'Indian groceries',
    'chips wally': 'Walmart',
    'braums':'Braums',
    'braums':'Braums'
}

# Apply mapping to the 'Description' column
confidence['Description'] = confidence['Description'].str.lower().map(additional_mapping).fillna(confidence['Description'])

# %%
pd.options.display.max_rows = None

value_counts = confidence['Description'].value_counts()
print(value_counts)
# Out:
# Description
# Indian groceries          125
# Walmart                    81
# Costco & similar           60
# Indian restaurants         43
# Milk and Beverages         40
# Halal Chicken              37
# American Fast Foods        33
# Braums                     30
# Household                  27
# Movie                      19
# Gas                        15
# Uber_and_Lyft              15
# Trip                        5
# Other                       5
# Unknown                     4
# braums                      4
# Milk and Beverages          3
# kroger                      3
# Desserts                    3
# coke                        2
# water                       2
# Entertainment               2
# Bakery & Dairy              2
# sarigama veggies            1
# Alcoholic Beverages         1
# Electronics                 1
# plantain chips              1
# Bar & Pub                   1
# braums & milk               1
# mushroom                    1
# ...

# %%
#miscelleneous mappings

# Define the mappings for specific items
specific_mappings = {
    'Trip': 'Trips and Other Activities',
    'Other': 'Trips and Other Activities',
    'Unknown': 'Trips and Other Activities',
    'braums': 'Braums',
    'Milk and Beverages': 'Milk and Beverages',
    'kroger': 'Costco & similar',
    'Desserts': 'Milk and Beverages',
    'coke': 'Milk and Beverages',
    'water': 'Walmart',
    'Entertainment': 'Trips and Other Activities',
    'Bakery & Dairy': 'Milk and Beverages',
    'sarigama veggies': 'Indian groceries',
    'Alcoholic Beverages': 'Beverages',
    'Electronics': 'Household',
    'plantain chips': 'Chips and Snacks',
    'Bar & Pub': 'Trips and Other Activities',
    'braums & milk': 'Braums',
    'mushroom': 'Walmart',
    'wally tomato': 'Walmart',
    'sams': 'Costco & similar',
    'పిస్తా హౌస్': 'Indian restaurants',
    'spices': 'Indian groceries',
    'veggies only': 'Indian groceries',
    'salt': 'Indian groceries',
    'Vegetables': 'Walmart',
    'amazon': 'Movie',
    'groceries': 'Indian groceries',
    'reddy dabha': 'Indian restaurants',
    'whipping cream': 'Milk and Beverages',
    'mcd': 'American Fast Foods',
    'wine glasses': 'Milk and Beverages',
    "dunkin'": 'American Fast Foods',
    'austin tropical drink': 'Milk and Beverages',
    'oasis lake and gas': 'Gas',
    'water case': 'Walmart',
    'cheese cake': 'Milk and Beverages',
    'insurance': 'Trips and Other Activities',
    'avatar': 'Movie',
    'guru walmart': 'Walmart',
    'toll': 'Trips and Other Activities',
    'temple': 'Trips and Other Activities',
    'tempered glass': 'Household',
    'Fruits': 'Walmart',
    'coconut': 'Trips and Other Activities'
}

confidence['Description'] = confidence['Description'].map(specific_mappings).fillna(confidence['Description'])

# %%
# Out:
# Description
# Indian groceries              125
# Walmart                        81
# Costco & similar               60
# Milk and Beverages             57
# Indian restaurants             43
# Halal Chicken                  37
# American Fast Foods            33
# Braums                         30
# Household                      27
# Movie                          19
# Gas                            15
# Uber_and_Lyft                  15
# Trips and Other Activities     10
# braums                          4
# Milk and Beverages              3
# kroger                          3
# coke                            2
# water                           2
# groceries                       1
# mushroom                        1
# braums & milk                   1
# whipping cream                  1
# పిస్తా హౌస్                     1
# wally tomato                    1
# spices                          1
# salt                            1
# plantain chips                  1
# ...

# %%
confidence.to_csv('confidence_transformed.csv', index=False)
